# %% [markdown]
# ## Checking for missing values using isnull() and notnull()

# %% [markdown]
# ### isnull(): trả về true nếu null
#
# Syntax: *pd.isnull(dataframe) or dataframe.isnull()*

# %% [markdown]
# vd1

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from list
df = pd.DataFrame(dict)

# using isnull() function
# trả về giá trị boolean của dataframe. True nếu null
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %% [markdown]
# vd2

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# creating bool series True for NaN values in column Gender
bool_series = pd.isnull(data["Gender"])

# filtering data
# displaying data only with Gender = NaN
# Khi sử dụng một Series Boolean trong dấu ngoặc vuông, Pandas sẽ lọc và chỉ trả về các hàng giá trị True.
data[bool_series]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# ...

# %% [markdown]
# ### notnull(): trả về false nếu null
#
# Syntax: *pd.notnull(dataframe) or dataframe.notnull()*

# %% [markdown]
# vd1

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe using dictionary
df = pd.DataFrame(dict)

# using notnull() function
df.notnull()
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %% [markdown]
# vd2

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# creating bool series True for NaN values
bool_series = pd.notnull(data["Gender"])

# filtering data
# displaying data only with Gender = Not NaN. True ở đây là notnull
data[bool_series]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# ## Filling missing values using fillna(), replace() and interpolate()

# %% [markdown]
# ### fillna()

# %% [markdown]
# Syntax: *DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)*

# %% [markdown]
# * value: giá trị được dùng để thay thế các giá trị NaN
# * method: Phương pháp để thay thế giá trị NaN, có thể là 'ffill' (forward fill: trước đó) hoặc 'bfill' (backward fill: ngay sau đó)
# * axis: 0: Thay thế dọc theo hàng (từng cột một).
# 1: Thay thế ngang theo cột (từng hàng một)
# * inplace: False (mặc định): Trả về một DataFrame mới với các giá trị NaN đã được thay thế. True: Thay đổi trực tiếp DataFrame hiện tại mà không tạo DataFrame mới.
# * limit: giới hạn số lượng NaN sẽ được thay thế
# * downcast: Xác định xem có cần cố gắng chuyển đổi kiểu dữ liệu của các giá trị thay thế hay không.
# * **kwargs: Các tham số bổ sung khác có thể được truyền vào, tương tự như trong các hàm Pandas khác.

# %% [markdown]
# vd1

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling missing value using fillna()
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# vd2

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling a missing value with previous ones
# điền null bằng giá trị trước nó
# pad = padding = ffill
df.fillna(method ='pad')
# Out:
# <ipython-input-14-e4c07d30528d>:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='pad')
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %% [markdown]
# vd3

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# filling  null value using fillna() function
df.fillna(method ='bfill')
# Out:
# <ipython-input-15-5999405c0abf>:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='bfill')
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %% [markdown]
# vd4: in dòng 10->24 trong tệp

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# Printing the first 10 to 24 rows of
# the data frame for visualization
data[10:25]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ...

# %% [markdown]
# phát hiện NaN ở cột gender

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# filling a null values using fillna()
data["Gender"].fillna("No Gender", inplace = True)

data
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# ### replace()

# %% [markdown]
# Syntax: *DataFrame.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method=’pad’, axis=None)*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# vd1

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# Printing the first 10 to 24 rows of
# the data frame for visualization
data[10:25]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 10     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 13       Gary    Male   1/27/2008        11:40 PM  109831    5.831
# 14   Kimberly  Female   1/14/1999         7:13 AM   41426   14.543
# 15    Lillian  Female    6/5/2016         6:09 AM   59414    1.256
# 16     Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 17      Shawn    Male   12/7/1986         7:45 PM  111737    6.414
# 18      Diana  Female  10/23/1981        10:27 AM  132940   19.082
# 19      Donna  Female   7/22/2010         3:48 AM   81014    1.894
# 20       Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 21    Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 22     Joshua     NaN    3/8/2012         1:58 AM   90816   18.816
# ...

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# will replace  Nan value in dataframe with value -99
data.replace(to_replace = np.nan, value = -99)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     -99  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   -99
# ...

# %% [markdown]
# ### interpolate() : nội suy

# %% [markdown]
# DataFrame.interpolate(method='linear', axis=0, limit=None, inplace=False, limit_direction='forward', limit_area=None, downcast=None, **kwargs)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# importing pandas as pd
import pandas as pd

# Creating the dataframe
df = pd.DataFrame({'A':[12, 4, 5, None, 1],
                   'B':[None, 2, 54, 3, None],
                   'C':[20, 16, None, 3, 8],
                   'D':[14, 3, None, None, 6]})

# Print the dataframe
df
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
# to interpolate the missing values
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %% [markdown]
# *Như chúng ta có thể thấy đầu ra, các giá trị ở hàng đầu tiên không thể được điền vì hướng điền các giá trị là về phía trước và không có giá trị nào trước đó có thể được sử dụng trong phép nội suy*

# %% [markdown]
# ## giải thích các pp nội suy

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dropping missing values using dropna()

# %% [markdown]
# ### dropna()

# %% [markdown]
# *DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# vd1: bỏ row nào chứa NaN hoặc thiếu

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# using dropna() function : drop mọi row có NaN
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %% [markdown]
# vd2: bỏ row nào có tất cả col chứa NaN hoặc miss

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 1          NaN           NaN          NaN           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

df = pd.DataFrame(dict)

# using dropna() function
df.dropna(how = 'all')
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0

# %% [markdown]
# vd3: Dropping columns with at least 1 null value.

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[60, 67, 68, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 1          NaN           NaN          NaN            67
# 2          NaN          45.0         80.0            68
# 3         95.0          56.0         98.0            65

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of lists
dict = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[60, 67, 68, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)

# using dropna() function
df.dropna(axis = 1)
# Out:
#    Fourth Score
# 0            60
# 1            67
# 2            68
# 3            65

# %% [markdown]
# vd4: Dropping Rows with at least 1 null value in CSV file

# %%
# importing pandas module
import pandas as pd

# making data frame from csv file
data = pd.read_csv("/content/Employees data.csv")

# making new data frame with dropped NA values
new_data = data.dropna(axis = 0, how ='any')

new_data
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
print("Old data frame length", len(data))
print("New data frame length", len(new_data))
print("Number of rows with at least 1 NA value: ", (len(data)-len(new_data)))
# Out:
# Old data frame length 1000
# New data frame length 764
# Number of rows with at least 1 NA value:  236
